# %% [markdown]
# # Chickpea example

# %% [markdown]
# ## Setup

# %%
import os
from mtmlsem import mtmlModel, Data, CVset
from pandas import read_csv
from semopy.efa import explore_cfa_model

path_data = 'data_cicer/'
file_phens = path_data + 'data_phens.txt'
file_snps = path_data + 'snp_2579_renamed.txt'
snp_pref = 'Ca'

# %% [markdown]
# ## Read data

# %%
data_phens = read_csv(file_phens, sep='\t', index_col=0)

print(data_phens.isna().sum(axis=0))

# Remove missing data
data_phens = data_phens.loc[data_phens.isna().sum(axis=1) == 0, :]
data_phens = data_phens.iloc[:, list(data_phens.nunique() > 2)]
data_snps = read_csv(file_snps, sep='\t', index_col=0)

# Create data object
data = Data(d_snps=data_snps, d_phens=data_phens)
print(data.n_samples)
# Out:
# Germ            0
# GBegF           0
# BegFEndF        0
# EndFBegM        0
# BegMEndM        0
# FloCol          0
# StemCol         0
# BushShape       0
# LeafSize        0
# FlowStemCol     0
# AscoRes         0
# StemBr          0
# StemL1ord       0
# StemBr1ord      0
# StemBr2ord      0
# PodD            0
# PodS            0
# Height          0
# Hlp             0
# NoPodsWeight    0
# PodsWeight      0
# PodsNumber      0
# SeedsNumber     0
# SeedsWeight     0
# PodShape        0
# PodLength       0
# PodWidth        0
# SeedShape       0
# SeedCol         0
# Seed1000W       0
# dtype: int64
# Imputation of phenotypes..
# Imputation of snps..
# Imputation is done.
# 404

# %% [markdown]
# ## Create model

# %%
model = mtmlModel(data=data)
# Out:
# SEM model was not defined

# %%
model.get_lat_struct()
model.show_mod()
# Out:
# Type of the latent structure is unconnected
# ======== show models ========
# # Model mod0
# F0 =~ PodsWeight + PodsNumber + SeedsNumber + SeedsWeight
# # Model mod1
# F1 =~ NoPodsWeight + PodShape + PodLength + PodWidth + Seed1000W
# # Model mod2
# F2 =~ FloCol + StemCol + SeedShape + SeedCol
# # Model mod3
# F3 =~ BegFEndF + EndFBegM
# # Model mod4
# F4 =~ Height + Hlp
# =============================

# %% [markdown]
# ## Add SNPs

# %%
model = model.add_snps(snp_pref=snp_pref)
# Out:
# -----------
# F0 =~ 1.0 * PodsWeight
# F0 =~ 1.993161755577956 * PodsNumber
# F0 =~ 1.8888180196854722 * SeedsNumber
# F0 =~ 1.9501172366847586 * SeedsWeight
# Skip 0 SNPs
# 2.876092537462682e-07
# F0 =~ 1.0 * PodsWeight
# F0 =~ 1.993161755577956 * PodsNumber
# F0 =~ 1.8888180196854722 * SeedsNumber
# F0 =~ 1.9501172366847586 * SeedsWeight
# F0 ~ -0.1838721852909942*Ca5_39720969
# Skip 2099 SNPs
# 0.0
# F0 =~ 1.0 * PodsWeight
# F0 =~ 1.993161755577956 * PodsNumber
# F0 =~ 1.8888180196854722 * SeedsNumber
# F0 =~ 1.9501172366847586 * SeedsWeight
# F0 ~ -0.1838721852909942*Ca5_39720969
# F0 ~ -0.1569318280485848*Ca7_30930779
# Skip 2255 SNPs
# 3.552713678800501e-15
# F0 =~ 1.0 * PodsWeight
# F0 =~ 1.993161755577956 * PodsNumber
# F0 =~ 1.8888180196854722 * SeedsNumber
# F0 =~ 1.9501172366847586 * SeedsWeight
# F0 ~ -0.1838721852909942*Ca5_39720969
# F0 ~ -0.1569318280485848*Ca7_30930779
# F0 ~ 0.14622670780325292*Ca3_10062634
# Skip 2263 SNPs
# NO SNPs added
# -----------
# -----------
# -----------
# F0 =~ 1.0 * PodsWeight
# F0 =~ 1.993161755577956 * PodsNumber
# F0 =~ 1.8888180196854722 * SeedsNumber
# F0 =~ 1.9501172366847586 * SeedsWeight
# F0 ~ -0.1838721852909942*Ca5_39720969
# F0 ~ -0.1569318280485848*Ca7_30930779
# F0 ~ 0.14622670780325292*Ca3_10062634
# Skip 0 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# 4.934319619565031e-10
# F0 =~ 1.0 * PodsWeight
# F0 =~ 1.993161755577956 * PodsNumber
# F0 =~ 1.8888180196854722 * SeedsNumber
# F0 =~ 1.9501172366847586 * SeedsWeight
# F0 ~ -0.1838721852909942*Ca5_39720969
# F0 ~ -0.1569318280485848*Ca7_30930779
# F0 ~ 0.14622670780325292*Ca3_10062634
# PodsWeight ~ -0.3031906361040511*Ca7_5728003
# Skip 938 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# -3.552713678800501e-15
# F0 =~ 1.0 * PodsWeight
# F0 =~ 1.993161755577956 * PodsNumber
# F0 =~ 1.8888180196854722 * SeedsNumber
# F0 =~ 1.9501172366847586 * SeedsWeight
# F0 ~ -0.1838721852909942*Ca5_39720969
# F0 ~ -0.1569318280485848*Ca7_30930779
# F0 ~ 0.14622670780325292*Ca3_10062634
# PodsWeight ~ -0.3031906361040511*Ca7_5728003
# PodsWeight ~ -0.14768096530867986*Ca1_7793021
# Skip 2112 SNPs
# 0.0
# F0 =~ 1.0 * PodsWeight
# F0 =~ 1.993161755577956 * PodsNumber
# F0 =~ 1.8888180196854722 * SeedsNumber
# F0 =~ 1.9501172366847586 * SeedsWeight
# F0 ~ -0.1838721852909942*Ca5_39720969
# F0 ~ -0.1569318280485848*Ca7_30930779
# F0 ~ 0.14622670780325292*Ca3_10062634
# PodsWeight ~ -0.3031906361040511*Ca7_5728003
# PodsWeight ~ -0.14768096530867986*Ca1_7793021
# PodsWeight ~ 0.35290970835804203*Ca7_21019002
# Skip 2251 SNPs
# NO SNPs added
# -----------
# -----------
# -----------
# F0 =~ 1.0 * PodsWeight
# F0 =~ 1.993161755577956 * PodsNumber
# F0 =~ 1.8888180196854722 * SeedsNumber
# F0 =~ 1.9501172366847586 * SeedsWeight
# F0 ~ -0.1838721852909942*Ca5_39720969
# F0 ~ -0.1569318280485848*Ca7_30930779
# F0 ~ 0.14622670780325292*Ca3_10062634
# PodsWeight ~ -0.3031906361040511*Ca7_5728003
# PodsWeight ~ -0.14768096530867986*Ca1_7793021
# PodsWeight ~ 0.35290970835804203*Ca7_21019002
# Skip 0 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# 1.3064482828895052e-09
# F0 =~ 1.0 * PodsWeight
# F0 =~ 1.993161755577956 * PodsNumber
# F0 =~ 1.8888180196854722 * SeedsNumber
# F0 =~ 1.9501172366847586 * SeedsWeight
# F0 ~ -0.1838721852909942*Ca5_39720969
# F0 ~ -0.1569318280485848*Ca7_30930779
# F0 ~ 0.14622670780325292*Ca3_10062634
# PodsWeight ~ -0.3031906361040511*Ca7_5728003
# PodsWeight ~ -0.14768096530867986*Ca1_7793021
# PodsWeight ~ 0.35290970835804203*Ca7_21019002
# SeedsWeight ~ -0.32574867389324846*Ca6_35046173
# Skip 953 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# 1.0879093181870303e-08
# F0 =~ 1.0 * PodsWeight
# F0 =~ 1.993161755577956 * PodsNumber
# F0 =~ 1.8888180196854722 * SeedsNumber
# F0 =~ 1.9501172366847586 * SeedsWeight
# F0 ~ -0.1838721852909942*Ca5_39720969
# F0 ~ -0.1569318280485848*Ca7_30930779
# F0 ~ 0.14622670780325292*Ca3_10062634
# PodsWeight ~ -0.3031906361040511*Ca7_5728003
# PodsWeight ~ -0.14768096530867986*Ca1_7793021
# PodsWeight ~ 0.35290970835804203*Ca7_21019002
# SeedsWeight ~ -0.32574867389324846*Ca6_35046173
# SeedsWeight ~ -0.1312914531599416*Ca6_8894185
# Skip 2266 SNPs
# NO SNPs added
# -----------
# -----------
# -----------
# F0 =~ 1.0 * PodsWeight
# F0 =~ 1.993161755577956 * PodsNumber
# F0 =~ 1.8888180196854722 * SeedsNumber
# F0 =~ 1.9501172366847586 * SeedsWeight
# F0 ~ -0.1838721852909942*Ca5_39720969
# F0 ~ -0.1569318280485848*Ca7_30930779
# F0 ~ 0.14622670780325292*Ca3_10062634
# PodsWeight ~ -0.3031906361040511*Ca7_5728003
# PodsWeight ~ -0.14768096530867986*Ca1_7793021
# PodsWeight ~ 0.35290970835804203*Ca7_21019002
# SeedsWeight ~ -0.32574867389324846*Ca6_35046173
# SeedsWeight ~ -0.1312914531599416*Ca6_8894185
# Skip 0 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Solver didnt converge, see SolverResult.
# -3.552713678800501e-15
# F0 =~ 1.0 * PodsWeight
# F0 =~ 1.993161755577956 * PodsNumber
# F0 =~ 1.8888180196854722 * SeedsNumber
# F0 =~ 1.9501172366847586 * SeedsWeight
# F0 ~ -0.1838721852909942*Ca5_39720969
# F0 ~ -0.1569318280485848*Ca7_30930779
# F0 ~ 0.14622670780325292*Ca3_10062634
# PodsWeight ~ -0.3031906361040511*Ca7_5728003
# PodsWeight ~ -0.14768096530867986*Ca1_7793021
# PodsWeight ~ 0.35290970835804203*Ca7_21019002
# SeedsWeight ~ -0.32574867389324846*Ca6_35046173
# SeedsWeight ~ -0.1312914531599416*Ca6_8894185
# SeedsNumber ~ 0.19015729331657133*Ca4_37047364
# Skip 1521 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# 0.0
# F0 =~ 1.0 * PodsWeight
# F0 =~ 1.993161755577956 * PodsNumber
# F0 =~ 1.8888180196854722 * SeedsNumber
# F0 =~ 1.9501172366847586 * SeedsWeight
# F0 ~ -0.1838721852909942*Ca5_39720969
# F0 ~ -0.1569318280485848*Ca7_30930779
# F0 ~ 0.14622670780325292*Ca3_10062634
# PodsWeight ~ -0.3031906361040511*Ca7_5728003
# PodsWeight ~ -0.14768096530867986*Ca1_7793021
# PodsWeight ~ 0.35290970835804203*Ca7_21019002
# SeedsWeight ~ -0.32574867389324846*Ca6_35046173
# SeedsWeight ~ -0.1312914531599416*Ca6_8894185
# SeedsNumber ~ 0.19015729331657133*Ca4_37047364
# SeedsNumber ~ 0.11548496857805855*Ca7_33457287
# Skip 2271 SNPs
# NO SNPs added
# -----------
# -----------
# -----------
# F0 =~ 1.0 * PodsWeight
# F0 =~ 1.993161755577956 * PodsNumber
# F0 =~ 1.8888180196854722 * SeedsNumber
# F0 =~ 1.9501172366847586 * SeedsWeight
# F0 ~ -0.1838721852909942*Ca5_39720969
# F0 ~ -0.1569318280485848*Ca7_30930779
# F0 ~ 0.14622670780325292*Ca3_10062634
# PodsWeight ~ -0.3031906361040511*Ca7_5728003
# PodsWeight ~ -0.14768096530867986*Ca1_7793021
# PodsWeight ~ 0.35290970835804203*Ca7_21019002
# SeedsWeight ~ -0.32574867389324846*Ca6_35046173
# SeedsWeight ~ -0.1312914531599416*Ca6_8894185
# SeedsNumber ~ 0.19015729331657133*Ca4_37047364
# SeedsNumber ~ 0.11548496857805855*Ca7_33457287
# Skip 0 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Solver didnt converge, see SolverResult.
# NO SNPs added
# -----------
# -----------
# -----------
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# Skip 0 SNPs
# 0.0
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# Skip 1167 SNPs
# NO SNPs added
# -----------
# -----------
# -----------
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# Skip 0 SNPs
# 0.0
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# Skip 1844 SNPs
# -1.4210854715202004e-14
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# Skip 2178 SNPs
# 1.2717723762989408e-08
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# Skip 2197 SNPs
# 1.8653773459220702e-07
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Skip 2270 SNPs
# NO SNPs added
# -----------
# -----------
# -----------
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Skip 0 SNPs
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# 0.0
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Skip 1935 SNPs
# 7.732657003600707e-08
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Seed1000W ~ -0.2415124567512738*Ca6_56158213
# Skip 2157 SNPs
# -1.7763568394002505e-15
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Seed1000W ~ -0.2415124567512738*Ca6_56158213
# Seed1000W ~ -0.2612830821520507*Ca6_59115549
# Skip 2239 SNPs
# 2.181305482906737e-07
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Seed1000W ~ -0.2415124567512738*Ca6_56158213
# Seed1000W ~ -0.2612830821520507*Ca6_59115549
# Seed1000W ~ 0.19912841811722343*Ca7_6324745
# Skip 2256 SNPs
# NO SNPs added
# -----------
# -----------
# -----------
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Seed1000W ~ -0.2415124567512738*Ca6_56158213
# Seed1000W ~ -0.2612830821520507*Ca6_59115549
# Seed1000W ~ 0.19912841811722343*Ca7_6324745
# Skip 0 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# -3.552713678800501e-15
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Seed1000W ~ -0.2415124567512738*Ca6_56158213
# Seed1000W ~ -0.2612830821520507*Ca6_59115549
# Seed1000W ~ 0.19912841811722343*Ca7_6324745
# PodWidth ~ 0.25662632181290723*Ca4_8479518
# Skip 2192 SNPs
# -3.552713678800501e-15
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Seed1000W ~ -0.2415124567512738*Ca6_56158213
# Seed1000W ~ -0.2612830821520507*Ca6_59115549
# Seed1000W ~ 0.19912841811722343*Ca7_6324745
# PodWidth ~ 0.25662632181290723*Ca4_8479518
# PodWidth ~ 0.12164527342489422*Ca7_3600987
# Skip 2244 SNPs
# 1.4306930218310754e-07
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Seed1000W ~ -0.2415124567512738*Ca6_56158213
# Seed1000W ~ -0.2612830821520507*Ca6_59115549
# Seed1000W ~ 0.19912841811722343*Ca7_6324745
# PodWidth ~ 0.25662632181290723*Ca4_8479518
# PodWidth ~ 0.12164527342489422*Ca7_3600987
# PodWidth ~ -0.12712359171417506*Ca1_18381505
# Skip 2272 SNPs
# NO SNPs added
# -----------
# -----------
# -----------
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Seed1000W ~ -0.2415124567512738*Ca6_56158213
# Seed1000W ~ -0.2612830821520507*Ca6_59115549
# Seed1000W ~ 0.19912841811722343*Ca7_6324745
# PodWidth ~ 0.25662632181290723*Ca4_8479518
# PodWidth ~ 0.12164527342489422*Ca7_3600987
# PodWidth ~ -0.12712359171417506*Ca1_18381505
# Skip 0 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# 3.109478363683138e-08
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Seed1000W ~ -0.2415124567512738*Ca6_56158213
# Seed1000W ~ -0.2612830821520507*Ca6_59115549
# Seed1000W ~ 0.19912841811722343*Ca7_6324745
# PodWidth ~ 0.25662632181290723*Ca4_8479518
# PodWidth ~ 0.12164527342489422*Ca7_3600987
# PodWidth ~ -0.12712359171417506*Ca1_18381505
# PodLength ~ 0.1537770619261997*Ca1_35261112
# Skip 2013 SNPs
# WARNING:root:Solver didnt converge, see SolverResult.
# 2.426681202649661e-07
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Seed1000W ~ -0.2415124567512738*Ca6_56158213
# Seed1000W ~ -0.2612830821520507*Ca6_59115549
# Seed1000W ~ 0.19912841811722343*Ca7_6324745
# PodWidth ~ 0.25662632181290723*Ca4_8479518
# PodWidth ~ 0.12164527342489422*Ca7_3600987
# PodWidth ~ -0.12712359171417506*Ca1_18381505
# PodLength ~ 0.1537770619261997*Ca1_35261112
# PodLength ~ 0.16645109015587778*Ca3_28094292
# Skip 2239 SNPs
# 1.2434497875801753e-14
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Seed1000W ~ -0.2415124567512738*Ca6_56158213
# Seed1000W ~ -0.2612830821520507*Ca6_59115549
# Seed1000W ~ 0.19912841811722343*Ca7_6324745
# PodWidth ~ 0.25662632181290723*Ca4_8479518
# PodWidth ~ 0.12164527342489422*Ca7_3600987
# PodWidth ~ -0.12712359171417506*Ca1_18381505
# PodLength ~ 0.1537770619261997*Ca1_35261112
# PodLength ~ 0.16645109015587778*Ca3_28094292
# PodLength ~ 0.26745877809053076*Ca1_11229616
# Skip 2253 SNPs
# 1.7763568394002505e-15
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Seed1000W ~ -0.2415124567512738*Ca6_56158213
# Seed1000W ~ -0.2612830821520507*Ca6_59115549
# Seed1000W ~ 0.19912841811722343*Ca7_6324745
# PodWidth ~ 0.25662632181290723*Ca4_8479518
# PodWidth ~ 0.12164527342489422*Ca7_3600987
# PodWidth ~ -0.12712359171417506*Ca1_18381505
# PodLength ~ 0.1537770619261997*Ca1_35261112
# PodLength ~ 0.16645109015587778*Ca3_28094292
# PodLength ~ 0.26745877809053076*Ca1_11229616
# PodLength ~ 0.11332663794211074*Ca7_15929893
# Skip 2272 SNPs
# NO SNPs added
# -----------
# -----------
# -----------
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Seed1000W ~ -0.2415124567512738*Ca6_56158213
# Seed1000W ~ -0.2612830821520507*Ca6_59115549
# Seed1000W ~ 0.19912841811722343*Ca7_6324745
# PodWidth ~ 0.25662632181290723*Ca4_8479518
# PodWidth ~ 0.12164527342489422*Ca7_3600987
# PodWidth ~ -0.12712359171417506*Ca1_18381505
# PodLength ~ 0.1537770619261997*Ca1_35261112
# PodLength ~ 0.16645109015587778*Ca3_28094292
# PodLength ~ 0.26745877809053076*Ca1_11229616
# PodLength ~ 0.11332663794211074*Ca7_15929893
# Skip 0 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Fisher Information Matrix is not PD.Moore-Penrose inverse will be used instead of Cholesky decomposition. See 10.1109/TSP.2012.2208105.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# 2.590478942465779e-10
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Seed1000W ~ -0.2415124567512738*Ca6_56158213
# Seed1000W ~ -0.2612830821520507*Ca6_59115549
# Seed1000W ~ 0.19912841811722343*Ca7_6324745
# PodWidth ~ 0.25662632181290723*Ca4_8479518
# PodWidth ~ 0.12164527342489422*Ca7_3600987
# PodWidth ~ -0.12712359171417506*Ca1_18381505
# PodLength ~ 0.1537770619261997*Ca1_35261112
# PodLength ~ 0.16645109015587778*Ca3_28094292
# PodLength ~ 0.26745877809053076*Ca1_11229616
# PodLength ~ 0.11332663794211074*Ca7_15929893
# NoPodsWeight ~ 0.30977254002566873*Ca8_10314452
# Skip 1263 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# 1.0061294020147216e-09
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Seed1000W ~ -0.2415124567512738*Ca6_56158213
# Seed1000W ~ -0.2612830821520507*Ca6_59115549
# Seed1000W ~ 0.19912841811722343*Ca7_6324745
# PodWidth ~ 0.25662632181290723*Ca4_8479518
# PodWidth ~ 0.12164527342489422*Ca7_3600987
# PodWidth ~ -0.12712359171417506*Ca1_18381505
# PodLength ~ 0.1537770619261997*Ca1_35261112
# PodLength ~ 0.16645109015587778*Ca3_28094292
# PodLength ~ 0.26745877809053076*Ca1_11229616
# PodLength ~ 0.11332663794211074*Ca7_15929893
# NoPodsWeight ~ 0.30977254002566873*Ca8_10314452
# NoPodsWeight ~ -0.23652934480687868*Ca5_20853333
# Skip 1695 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Fisher Information Matrix is not PD.Moore-Penrose inverse will be used instead of Cholesky decomposition. See 10.1109/TSP.2012.2208105.
# WARNING:root:Solver didnt converge, see SolverResult.
# 1.1607923511292029e-09
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Seed1000W ~ -0.2415124567512738*Ca6_56158213
# Seed1000W ~ -0.2612830821520507*Ca6_59115549
# Seed1000W ~ 0.19912841811722343*Ca7_6324745
# PodWidth ~ 0.25662632181290723*Ca4_8479518
# PodWidth ~ 0.12164527342489422*Ca7_3600987
# PodWidth ~ -0.12712359171417506*Ca1_18381505
# PodLength ~ 0.1537770619261997*Ca1_35261112
# PodLength ~ 0.16645109015587778*Ca3_28094292
# PodLength ~ 0.26745877809053076*Ca1_11229616
# PodLength ~ 0.11332663794211074*Ca7_15929893
# NoPodsWeight ~ 0.30977254002566873*Ca8_10314452
# NoPodsWeight ~ -0.23652934480687868*Ca5_20853333
# NoPodsWeight ~ 0.4171340975092178*Ca6_47657340
# Skip 2040 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# 0.0
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.2655507352714315 * PodShape
# F1 =~ 2.305171795477748 * PodLength
# F1 =~ 2.3253993057364752 * PodWidth
# F1 =~ 2.2772009146448378 * Seed1000W
# F1 ~ -0.2803978909533043*Ca7_5728003
# PodShape ~ 0.16172616994582173*Ca3_26879200
# PodShape ~ 0.22166832765191313*Ca5_24488052
# PodShape ~ 0.10412336637546575*Ca4_37300412
# PodShape ~ 0.21330130224640176*Ca6_47657340
# Seed1000W ~ 0.24802096590997608*Ca3_3888778
# Seed1000W ~ -0.2415124567512738*Ca6_56158213
# Seed1000W ~ -0.2612830821520507*Ca6_59115549
# Seed1000W ~ 0.19912841811722343*Ca7_6324745
# PodWidth ~ 0.25662632181290723*Ca4_8479518
# PodWidth ~ 0.12164527342489422*Ca7_3600987
# PodWidth ~ -0.12712359171417506*Ca1_18381505
# PodLength ~ 0.1537770619261997*Ca1_35261112
# PodLength ~ 0.16645109015587778*Ca3_28094292
# PodLength ~ 0.26745877809053076*Ca1_11229616
# PodLength ~ 0.11332663794211074*Ca7_15929893
# NoPodsWeight ~ 0.30977254002566873*Ca8_10314452
# NoPodsWeight ~ -0.23652934480687868*Ca5_20853333
# NoPodsWeight ~ 0.4171340975092178*Ca6_47657340
# NoPodsWeight ~ -0.49911353284506227*Ca4_8165224
# Skip 2237 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# NO SNPs added
# -----------
# -----------
# -----------
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# Skip 0 SNPs
# 0.0
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# Skip 999 SNPs
# 1.7213967140605746e-08
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# Skip 2267 SNPs
# NO SNPs added
# -----------
# -----------
# -----------
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# Skip 0 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# 0.0
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# StemCol ~ -0.4094890818951717*Ca6_48295748
# Skip 862 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# 0.0
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# StemCol ~ -0.4094890818951717*Ca6_48295748
# StemCol ~ -0.532577488479672*Ca6_18802099
# Skip 1383 SNPs
# 2.6887151882704075e-07
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# StemCol ~ -0.4094890818951717*Ca6_48295748
# StemCol ~ -0.532577488479672*Ca6_18802099
# StemCol ~ -0.458403730440928*Ca1_1224263
# Skip 1630 SNPs
# 3.6832262217956213e-07
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# StemCol ~ -0.4094890818951717*Ca6_48295748
# StemCol ~ -0.532577488479672*Ca6_18802099
# StemCol ~ -0.458403730440928*Ca1_1224263
# StemCol ~ 0.27856842690283906*Ca6_26534883
# Skip 1840 SNPs
# 5.252734247562785e-07
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# StemCol ~ -0.4094890818951717*Ca6_48295748
# StemCol ~ -0.532577488479672*Ca6_18802099
# StemCol ~ -0.458403730440928*Ca1_1224263
# StemCol ~ 0.27856842690283906*Ca6_26534883
# StemCol ~ -0.2445541919008664*Ca2_32142844
# Skip 2006 SNPs
# 0.0
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# StemCol ~ -0.4094890818951717*Ca6_48295748
# StemCol ~ -0.532577488479672*Ca6_18802099
# StemCol ~ -0.458403730440928*Ca1_1224263
# StemCol ~ 0.27856842690283906*Ca6_26534883
# StemCol ~ -0.2445541919008664*Ca2_32142844
# StemCol ~ -0.4894034873892147*Ca8_11736056
# Skip 2139 SNPs
# 7.046853056635882e-08
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# StemCol ~ -0.4094890818951717*Ca6_48295748
# StemCol ~ -0.532577488479672*Ca6_18802099
# StemCol ~ -0.458403730440928*Ca1_1224263
# StemCol ~ 0.27856842690283906*Ca6_26534883
# StemCol ~ -0.2445541919008664*Ca2_32142844
# StemCol ~ -0.4894034873892147*Ca8_11736056
# StemCol ~ -0.14640674895014805*Ca5_36538079
# Skip 2259 SNPs
# 3.8226007781361204e-07
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# StemCol ~ -0.4094890818951717*Ca6_48295748
# StemCol ~ -0.532577488479672*Ca6_18802099
# StemCol ~ -0.458403730440928*Ca1_1224263
# StemCol ~ 0.27856842690283906*Ca6_26534883
# StemCol ~ -0.2445541919008664*Ca2_32142844
# StemCol ~ -0.4894034873892147*Ca8_11736056
# StemCol ~ -0.14640674895014805*Ca5_36538079
# StemCol ~ -0.4240040316832867*Ca5_30662807
# Skip 2270 SNPs
# 8.60936200552942e-07
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# StemCol ~ -0.4094890818951717*Ca6_48295748
# StemCol ~ -0.532577488479672*Ca6_18802099
# StemCol ~ -0.458403730440928*Ca1_1224263
# StemCol ~ 0.27856842690283906*Ca6_26534883
# StemCol ~ -0.2445541919008664*Ca2_32142844
# StemCol ~ -0.4894034873892147*Ca8_11736056
# StemCol ~ -0.14640674895014805*Ca5_36538079
# StemCol ~ -0.4240040316832867*Ca5_30662807
# StemCol ~ 0.5859113297082581*Ca1_9331447
# Skip 2274 SNPs
# NO SNPs added
# -----------
# -----------
# -----------
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# StemCol ~ -0.4094890818951717*Ca6_48295748
# StemCol ~ -0.532577488479672*Ca6_18802099
# StemCol ~ -0.458403730440928*Ca1_1224263
# StemCol ~ 0.27856842690283906*Ca6_26534883
# StemCol ~ -0.2445541919008664*Ca2_32142844
# StemCol ~ -0.4894034873892147*Ca8_11736056
# StemCol ~ -0.14640674895014805*Ca5_36538079
# StemCol ~ -0.4240040316832867*Ca5_30662807
# StemCol ~ 0.5859113297082581*Ca1_9331447
# Skip 0 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# 3.0029159603373046e-08
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# StemCol ~ -0.4094890818951717*Ca6_48295748
# StemCol ~ -0.532577488479672*Ca6_18802099
# StemCol ~ -0.458403730440928*Ca1_1224263
# StemCol ~ 0.27856842690283906*Ca6_26534883
# StemCol ~ -0.2445541919008664*Ca2_32142844
# StemCol ~ -0.4894034873892147*Ca8_11736056
# StemCol ~ -0.14640674895014805*Ca5_36538079
# StemCol ~ -0.4240040316832867*Ca5_30662807
# StemCol ~ 0.5859113297082581*Ca1_9331447
# SeedCol ~ -0.20960802390063393*Ca7_5559110
# Skip 1634 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# 1.1870281646508829e-07
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# StemCol ~ -0.4094890818951717*Ca6_48295748
# StemCol ~ -0.532577488479672*Ca6_18802099
# StemCol ~ -0.458403730440928*Ca1_1224263
# StemCol ~ 0.27856842690283906*Ca6_26534883
# StemCol ~ -0.2445541919008664*Ca2_32142844
# StemCol ~ -0.4894034873892147*Ca8_11736056
# StemCol ~ -0.14640674895014805*Ca5_36538079
# StemCol ~ -0.4240040316832867*Ca5_30662807
# StemCol ~ 0.5859113297082581*Ca1_9331447
# SeedCol ~ -0.20960802390063393*Ca7_5559110
# SeedCol ~ 0.3559045596772554*Ca8_4530592
# Skip 2173 SNPs
# 4.1381470694545897e-08
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# StemCol ~ -0.4094890818951717*Ca6_48295748
# StemCol ~ -0.532577488479672*Ca6_18802099
# StemCol ~ -0.458403730440928*Ca1_1224263
# StemCol ~ 0.27856842690283906*Ca6_26534883
# StemCol ~ -0.2445541919008664*Ca2_32142844
# StemCol ~ -0.4894034873892147*Ca8_11736056
# StemCol ~ -0.14640674895014805*Ca5_36538079
# StemCol ~ -0.4240040316832867*Ca5_30662807
# StemCol ~ 0.5859113297082581*Ca1_9331447
# SeedCol ~ -0.20960802390063393*Ca7_5559110
# SeedCol ~ 0.3559045596772554*Ca8_4530592
# SeedCol ~ 0.10590703719544656*Ca1_2309179
# Skip 2248 SNPs
# 0.0
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# StemCol ~ -0.4094890818951717*Ca6_48295748
# StemCol ~ -0.532577488479672*Ca6_18802099
# StemCol ~ -0.458403730440928*Ca1_1224263
# StemCol ~ 0.27856842690283906*Ca6_26534883
# StemCol ~ -0.2445541919008664*Ca2_32142844
# StemCol ~ -0.4894034873892147*Ca8_11736056
# StemCol ~ -0.14640674895014805*Ca5_36538079
# StemCol ~ -0.4240040316832867*Ca5_30662807
# StemCol ~ 0.5859113297082581*Ca1_9331447
# SeedCol ~ -0.20960802390063393*Ca7_5559110
# SeedCol ~ 0.3559045596772554*Ca8_4530592
# SeedCol ~ 0.10590703719544656*Ca1_2309179
# SeedCol ~ 0.2114722530875856*Ca5_33339443
# Skip 2272 SNPs
# NO SNPs added
# -----------
# -----------
# -----------
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# StemCol ~ -0.4094890818951717*Ca6_48295748
# StemCol ~ -0.532577488479672*Ca6_18802099
# StemCol ~ -0.458403730440928*Ca1_1224263
# StemCol ~ 0.27856842690283906*Ca6_26534883
# StemCol ~ -0.2445541919008664*Ca2_32142844
# StemCol ~ -0.4894034873892147*Ca8_11736056
# StemCol ~ -0.14640674895014805*Ca5_36538079
# StemCol ~ -0.4240040316832867*Ca5_30662807
# StemCol ~ 0.5859113297082581*Ca1_9331447
# SeedCol ~ -0.20960802390063393*Ca7_5559110
# SeedCol ~ 0.3559045596772554*Ca8_4530592
# SeedCol ~ 0.10590703719544656*Ca1_2309179
# SeedCol ~ 0.2114722530875856*Ca5_33339443
# Skip 0 SNPs
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# ...
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# 0.0
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# StemCol ~ -0.4094890818951717*Ca6_48295748
# StemCol ~ -0.532577488479672*Ca6_18802099
# StemCol ~ -0.458403730440928*Ca1_1224263
# StemCol ~ 0.27856842690283906*Ca6_26534883
# StemCol ~ -0.2445541919008664*Ca2_32142844
# StemCol ~ -0.4894034873892147*Ca8_11736056
# StemCol ~ -0.14640674895014805*Ca5_36538079
# StemCol ~ -0.4240040316832867*Ca5_30662807
# StemCol ~ 0.5859113297082581*Ca1_9331447
# SeedCol ~ -0.20960802390063393*Ca7_5559110
# SeedCol ~ 0.3559045596772554*Ca8_4530592
# SeedCol ~ 0.10590703719544656*Ca1_2309179
# SeedCol ~ 0.2114722530875856*Ca5_33339443
# SeedShape ~ -0.5395145050943977*Ca3_1871391
# SeedShape ~ 0.18416533850267153*Ca1_25737022
# SeedShape ~ 0.15738093164999278*Ca7_30930779
# SeedShape ~ -0.18087762498678056*Ca5_39545825
# SeedShape ~ 0.3205447961645593*Ca2_2608533
# SeedShape ~ -0.13486730885571424*Ca4_6297533
# SeedShape ~ 0.12600581407581773*Ca1_47067099
# SeedShape ~ 0.17978701223221977*Ca6_3149303
# FloCol ~ -0.17643889348381792*Ca4_14180446
# Skip 1683 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Solver didnt converge, see SolverResult.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# 6.14636341822461e-10
# F2 =~ 1.0 * FloCol
# F2 =~ 3.5387901188771473 * StemCol
# F2 =~ -1.044410506423987 * SeedShape
# F2 =~ 1.6297222765157966 * SeedCol
# F2 ~ 0.34748934364784606*Ca4_13593426
# F2 ~ 0.1322302887628678*Ca1_35502868
# StemCol ~ -0.4094890818951717*Ca6_48295748
# StemCol ~ -0.532577488479672*Ca6_18802099
# StemCol ~ -0.458403730440928*Ca1_1224263
# StemCol ~ 0.27856842690283906*Ca6_26534883
# StemCol ~ -0.2445541919008664*Ca2_32142844
# StemCol ~ -0.4894034873892147*Ca8_11736056
# StemCol ~ -0.14640674895014805*Ca5_36538079
# StemCol ~ -0.4240040316832867*Ca5_30662807
# StemCol ~ 0.5859113297082581*Ca1_9331447
# SeedCol ~ -0.20960802390063393*Ca7_5559110
# SeedCol ~ 0.3559045596772554*Ca8_4530592
# SeedCol ~ 0.10590703719544656*Ca1_2309179
# SeedCol ~ 0.2114722530875856*Ca5_33339443
# SeedShape ~ -0.5395145050943977*Ca3_1871391
# SeedShape ~ 0.18416533850267153*Ca1_25737022
# SeedShape ~ 0.15738093164999278*Ca7_30930779
# SeedShape ~ -0.18087762498678056*Ca5_39545825
# SeedShape ~ 0.3205447961645593*Ca2_2608533
# SeedShape ~ -0.13486730885571424*Ca4_6297533
# SeedShape ~ 0.12600581407581773*Ca1_47067099
# SeedShape ~ 0.17978701223221977*Ca6_3149303
# FloCol ~ -0.17643889348381792*Ca4_14180446
# FloCol ~ 0.1340233829490249*Ca1_18015960
# Skip 2239 SNPs
# WARNING:root:Fisher Information Matrix is not PD.Moore-Penrose inverse will be used instead of Cholesky decomposition. See 10.1109/TSP.2012.2208105.
# NO SNPs added
# -----------
# -----------
# -----------
# F3 =~ 1.0 * BegFEndF
# F3 =~ -1.9173427627185813 * EndFBegM
# Skip 0 SNPs
# 2.802469367679805e-10
# F3 =~ 1.0 * BegFEndF
# F3 =~ -1.9173427627185813 * EndFBegM
# F3 ~ -0.1988259388996768*Ca2_32110068
# Skip 1625 SNPs
# 0.0
# F3 =~ 1.0 * BegFEndF
# F3 =~ -1.9173427627185813 * EndFBegM
# F3 ~ -0.1988259388996768*Ca2_32110068
# F3 ~ 0.1636504843580095*Ca3_31423265
# Skip 1955 SNPs
# 0.0
# F3 =~ 1.0 * BegFEndF
# F3 =~ -1.9173427627185813 * EndFBegM
# F3 ~ -0.1988259388996768*Ca2_32110068
# F3 ~ 0.1636504843580095*Ca3_31423265
# F3 ~ -0.12204459449295726*Ca4_2145082
# Skip 2217 SNPs
# 7.87367238075376e-09
# F3 =~ 1.0 * BegFEndF
# F3 =~ -1.9173427627185813 * EndFBegM
# F3 ~ -0.1988259388996768*Ca2_32110068
# F3 ~ 0.1636504843580095*Ca3_31423265
# F3 ~ -0.12204459449295726*Ca4_2145082
# F3 ~ 0.17839877336740365*Ca6_53592514
# Skip 2254 SNPs
# 7.115388278577939e-09
# F3 =~ 1.0 * BegFEndF
# F3 =~ -1.9173427627185813 * EndFBegM
# F3 ~ -0.1988259388996768*Ca2_32110068
# F3 ~ 0.1636504843580095*Ca3_31423265
# F3 ~ -0.12204459449295726*Ca4_2145082
# F3 ~ 0.17839877336740365*Ca6_53592514
# F3 ~ -0.19172284785854796*Ca3_28269832
# Skip 2270 SNPs
# NO SNPs added
# -----------
# -----------
# -----------
# F3 =~ 1.0 * BegFEndF
# F3 =~ -1.9173427627185813 * EndFBegM
# F3 ~ -0.1988259388996768*Ca2_32110068
# F3 ~ 0.1636504843580095*Ca3_31423265
# F3 ~ -0.12204459449295726*Ca4_2145082
# F3 ~ 0.17839877336740365*Ca6_53592514
# F3 ~ -0.19172284785854796*Ca3_28269832
# Skip 0 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# 0.0
# F3 =~ 1.0 * BegFEndF
# F3 =~ -1.9173427627185813 * EndFBegM
# F3 ~ -0.1988259388996768*Ca2_32110068
# F3 ~ 0.1636504843580095*Ca3_31423265
# F3 ~ -0.12204459449295726*Ca4_2145082
# F3 ~ 0.17839877336740365*Ca6_53592514
# F3 ~ -0.19172284785854796*Ca3_28269832
# BegFEndF ~ 0.3994136926420266*Ca7_32678008
# Skip 1800 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2642/1944132135.py in <module>
# ----> 1 model = model.add_snps(snp_pref=snp_pref)
#
# ~/Documents/Pr/mtmlsem/mtmlsem/mtml_model.py in add_snps(self, snp_pref, n_iter)
#     150         self.gwas = dict()
#     151         for k, mod in self.mods.items():
# --> 152             self.mods[k], self.gwas[k], _ = add_snps(mod, self.data,
#     153                                                   snp_pref=snp_pref,
#     154                                                   n_iter=n_iter)
#
# ~/Documents/Pr/mtmlsem/mtmlsem/add_snps.py in add_snps(mod, data, thresh_mlr, thresh_sign_snp, thresh_abs_param, snp_pref, n_iter)
#     195         # print(mod_init)
#     196         print('-----------')
# --> 197         mod_init, gwas[variable], snps_added[variable] = add_snps_for_variable(mod_init, data, variable,
#     198                                       thresh_mlr=thresh_mlr,
#     199                                       thresh_sign_snp=thresh_sign_snp,
#
# ~/Documents/Pr/mtmlsem/mtmlsem/add_snps.py in add_snps_for_variable(mod, data, variable, thresh_mlr, thresh_sign_snp, thresh_abs_param, snp_pref, n_iter)
#     225         show(mod_init)
#     226         mod_new, snp_skip, snp_list = \
# --> 227             one_snp_for_variable(mod_init, data, variable,
#     228                                  snp_skip=snp_skip,
#     229                                  thresh_mlr=thresh_mlr,
#
# ~/Documents/Pr/mtmlsem/mtmlsem/add_snps.py in one_snp_for_variable(mod_init, data, variable, snp_skip, thresh_mlr, thresh_sign_snp, thresh_abs_param, snp_pref, echo)
#     325             data_tmp[v_tmp] = data.d_snps[snp]
#     326
# --> 327             obj = sem_mod_tmp.fit(data_tmp, clean_slate=True)
#     328
#     329             if empty_mod:
#
# ~/.local/lib/python3.9/site-packages/semopy/model.py in fit(self, data, cov, obj, solver, groups, clean_slate, regularization, n_samples, **kwargs)
#    1111                         constrs=self.constraints,
#    1112                         bounds=self.get_bounds(), **kwargs)
# -> 1113         res = solver.solve()
#    1114         res.name_obj = obj
#    1115         self.param_vals = res.x
#
# ~/.local/lib/python3.9/site-packages/semopy/solver.py in solve(self)
#      99         if self.method in self.custom_methods:
#     100             return self.custom_methods[self.method]()
# --> 101         res = self.scipy_solve()
#     102         if not res.success:
#     103             logging.warning('Solver didn''t converge, see SolverResult.')
#
# ~/.local/lib/python3.9/site-packages/semopy/solver.py in scipy_solve(self)
#     132                        constraints=self.constraints, **t)
#     133         else:
# --> 134             res = minimize(self.fun, self.start, jac=self.grad, bounds=self.bounds,
#     135                            constraints=self.constraints, options=self.options,
#     136                            method=self.method, **self.extra_options)
#
# /usr/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     629         return _minimize_cobyla(fun, x0, args, constraints, **options)
#     630     elif meth == 'slsqp':
# --> 631         return _minimize_slsqp(fun, x0, args, jac, bounds,
#     632                                constraints, callback=callback, **options)
#     633     elif meth == 'trust-constr':
#
# /usr/lib/python3.9/site-packages/scipy/optimize/slsqp.py in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, **unknown_options)
#     373
#     374     # ScalarFunction provides function and gradient evaluation
# --> 375     sf = _prepare_scalar_function(func, x, jac=jac, args=args, epsilon=eps,
#     376                                   finite_diff_rel_step=finite_diff_rel_step,
#     377                                   bounds=new_bounds)
#
# /usr/lib/python3.9/site-packages/scipy/optimize/optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     259     # ScalarFunction caches. Reuse of fun(x) during grad
#     260     # calculation reduces overall function evaluations.
# --> 261     sf = ScalarFunction(fun, x0, args, grad, hess,
#     262                         finite_diff_rel_step, bounds, epsilon=epsilon)
#     263
#
# /usr/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     138
#     139         self._update_fun_impl = update_fun
# --> 140         self._update_fun()
#     141
#     142         # Gradient evaluation
#
# /usr/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     231     def _update_fun(self):
#     232         if not self.f_updated:
# --> 233             self._update_fun_impl()
#     234             self.f_updated = True
#     235
#
# /usr/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     135
#     136         def update_fun():
# --> 137             self.f = fun_wrapped(self.x)
#     138
#     139         self._update_fun_impl = update_fun
#
# /usr/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     132             # Overwriting results in undefined behaviour because
#     133             # fun(self.x) will change self.x, with the two no longer linked.
# --> 134             return fun(np.copy(x), *args)
#     135
#     136         def update_fun():
#
# ~/.local/lib/python3.9/site-packages/semopy/model.py in obj_mlw(self, x)
#    1475         self.update_matrices(x)
#    1476         try:
# -> 1477             sigma, _ = self.calc_sigma()
#    1478             inv_sigma, logdet_sigma = chol_inv2(sigma)
#    1479         except np.linalg.LinAlgError:
#
# ~/.local/lib/python3.9/site-packages/semopy/model.py in calc_sigma(self)
#    1408         """
#    1409         beta, lamb, psi, theta = self.matrices[:4]
# -> 1410         c = np.linalg.inv(self.identity_c - beta)
#    1411         m = lamb @ c
#    1412         return m @ psi @ m.T + theta, (m, c)
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# ~/.local/lib/python3.9/site-packages/numpy/linalg/linalg.py in inv(a)
#     543     signature = 'D->D' if isComplexType(t) else 'd->d'
#     544     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 545     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     546     return wrap(ainv.astype(result_t, copy=False))
#     547
#
# KeyboardInterrupt:
