# %% [markdown]
# # Chickpea example

# %% [markdown]
# ## Setup

# %%
import os
from mtml_model import mtmlModel
from dataset import Data, CVset
from pandas import read_csv
from optimisation import *
from semopy.efa import explore_cfa_model
from utils import *

path_data = 'data_cicer/'
file_phens = path_data + 'data_phens.txt'
file_snps = path_data + 'snp_2579_renamed.txt'
snp_pref = 'Ca'

# %% [markdown]
# ## Read data

# %%
data_phens = read_csv(file_phens, sep='\t', index_col=0)

print(data_phens.isna().sum(axis=0))

# Remove missing data
data_phens = data_phens.loc[data_phens.isna().sum(axis=1) == 0, :]
data_phens = data_phens.iloc[:, list(data_phens.nunique() > 2)]
data_snps = read_csv(file_snps, sep='\t', index_col=0)

# Create data object
data = Data(d_snps=data_snps, d_phens=data_phens)
print(data.n_samples)
# Out:
# Germ            0
# GBegF           0
# BegFEndF        0
# EndFBegM        0
# BegMEndM        0
# FloCol          0
# StemCol         0
# BushShape       0
# LeafSize        0
# FlowStemCol     0
# AscoRes         0
# StemBr          0
# StemL1ord       0
# StemBr1ord      0
# StemBr2ord      0
# PodD            0
# PodS            0
# Height          0
# Hlp             0
# NoPodsWeight    0
# PodsWeight      0
# PodsNumber      0
# SeedsNumber     0
# SeedsWeight     0
# PodShape        0
# PodLength       0
# PodWidth        0
# SeedShape       0
# SeedCol         0
# Seed1000W       0
# dtype: int64
# 404

# %% [markdown]
# ## Create model

# %%
model = mtmlModel(data=data)
# Out:
# SEM model was not defined

# %%
model.get_lat_struct()
model.show_mod()
# Out:
# Type of the latent structure is unconnect
# ======== show models ========
# # Model mod0
# F0 =~ PodsWeight + PodsNumber + SeedsNumber + SeedsWeight
# # Model mod1
# F1 =~ NoPodsWeight + PodShape + PodLength + PodWidth + Seed1000W
# # Model mod2
# F2 =~ FloCol + StemCol + SeedShape + SeedCol
# # Model mod3
# F3 =~ BegFEndF + EndFBegM
# # Model mod4
# F4 =~ Height + Hlp
# =============================

# %% [markdown]
# ## Add SNPs

# %%
model = model.add_snps(snp_pref=snp_pref)
# Out:
# F0
# PodsNumber
# SeedsWeight
# PodsWeight
# SeedsNumber
# F0 =~ 1.0 * PodsWeight
# F0 =~ 0.9997553747355805 * PodsNumber
# F0 =~ 0.9071818056783406 * SeedsNumber
# F0 =~ 1.0759638553617537 * SeedsWeight
# F0
# F0 =~ 1.0 * PodsWeight
# F0 =~ 0.9997553747355805 * PodsNumber
# F0 =~ 0.9071818056783406 * SeedsNumber
# F0 =~ 1.0759638553617537 * SeedsWeight
# -----------
# 16.829923656290944 16.829923656290944
# Skip 0 SNPs
# 0.7189625998202747
# 16.829923656290944
# 0.7178690211083589
# 8.306973317872174
# 13.469395010682476 13.469395010682476
# Skip 423 SNPs
# 0.7423524955828835
# 13.469395010682476
# 0.7180327645599238
# 4.324537680509
# 11.606186203742588 11.606186203742588
# Skip 855 SNPs
# 0.7573263477964307
# 11.606186203742588
# 0.7179516697183779
# 2.6163558255534625
# 10.700739607585295 10.700739607585295
# Skip 1006 SNPs
# 0.7660398966927211
# 10.700739607585295
# 0.7178979415213913
# 1.785389679413349
# 10.071292874504355 10.071292874504355
# Skip 1046 SNPs
# 0.868058063920019
# 10.071292874504355
# 0.7182471031545754
# 1.4029834003126744
# 9.436412182502607 9.436412182502607
# Skip 1117 SNPs
# 0.8885931211440194
# 9.436412182502607
# 0.7181420210888176
# 0.8333059507878922
# 9.529330290000857 9.529330290000857
# Skip 1192 SNPs
# 0.9209614870334928
# 9.529330290000857
# 0.7185287877422031
# 0.8345709753927046
# 9.382384659741046 9.382384659741046
# Skip 1203 SNPs
# 0.9263634187578837
# 9.382384659741046
# 0.7186028140571041
# 0.8020510917017489
# 9.153732000557014 9.153732000557014
# Skip 1237 SNPs
# 0.930361133393788
# 9.153732000557014
# 0.7183681427330635
# 0.6875480606123396
# 8.96096581787409 8.96096581787409
# Skip 1405 SNPs
# 0.9332226678840865
# 8.96096581787409
# 0.7185195343255497
# 0.6050174524548062
# F0 =~ 1.0 * PodsWeight
# F0 =~ 0.9997553747355805 * PodsNumber
# F0 =~ 0.9071818056783406 * SeedsNumber
# F0 =~ 1.0759638553617537 * SeedsWeight
# F0 ~ -0.44538794410775767*Ca3_28437425
# F0 ~ 0.3227887260518876*Ca2_17161867
# F0 ~ 0.29802719680437206*Ca5_38015453
# F0 ~ 0.28453166147899506*Ca6_26469783
# F0 ~ 0.2839469827873234*Ca6_16385056
# F0 ~ -0.24419894830865163*Ca3_28269832
# F0 ~ -0.2482879103138365*Ca4_1394730
# F0 ~ 0.2333063512373397*Ca4_12690077
# F0 ~ -0.22814319862846602*Ca1_1033034
# F0 ~ -0.22965189126153024*Ca5_24904659
# -----------
# -----------
# F1
# PodShape
# PodLength
# PodWidth
# NoPodsWeight
# Seed1000W
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.1666642750085 * PodShape
# F1 =~ 1.5059751335472542 * PodLength
# F1 =~ 1.5254824041686028 * PodWidth
# F1 =~ 1.4200690004810044 * Seed1000W
# F1
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.1666642750085 * PodShape
# F1 =~ 1.5059751335472542 * PodLength
# F1 =~ 1.5254824041686028 * PodWidth
# F1 =~ 1.4200690004810044 * Seed1000W
# -----------
# 23.942438891704146 23.94243889170415
# Skip 0 SNPs
# 0.23172500370290994
# 23.94243889170415
# 0.10966128034580347
# 3.857708849273422
# 21.818333370065112 21.818333370065112
# Skip 115 SNPs
# 0.2807819752370797
# 21.818333370065112
# 0.11067085933201959
# 1.7616056318768436
# 20.965960320661797 20.965960320661797
# Skip 486 SNPs
# 0.28930290492973043
# 20.965960320661797
# 0.11078810523558325
# 0.8793282082283689
# 20.696108316994778 20.696108316994778
# Skip 503 SNPs
# 0.3348491230358448
# 20.696108316994778
# 0.11166375666914252
# 0.5926268428603656
# 20.46176576732075 20.46176576732075
# Skip 576 SNPs
# 0.40594466665242024
# 20.46176576732075
# 0.11293269323448207
# 0.33347700938951874
# 20.35784139985098 20.35784139985098
# Skip 730 SNPs
# 0.4683063870281803
# 20.35784139985098
# 0.11639991884774537
# 0.2391856374492285
# 20.238690161260944 20.238690161260937
# Skip 842 SNPs
# 0.5029027872874927
# 20.238690161260937
# 0.11729354470513664
# 0.16538682366373436
# 20.2148047934124 20.2148047934124
# Skip 1245 SNPs
# 0.5764637201627192
# 20.2148047934124
# 0.11919689516247445
# 0.1076861845817092
# 20.183886359722973 20.183886359722965
# Skip 1341 SNPs
# 0.6971350463194739
# 20.183886359722965
# 0.14894430605346587
# 0.08177966485605737
# 20.06465227928831 20.06465227928831
# Skip 1446 SNPs
# 0.7051707702008247
# 20.06465227928831
# 0.14413966833008462
# 0.01042289343140368
# F1 =~ 1.0 * NoPodsWeight
# F1 =~ -1.1666642750085 * PodShape
# F1 =~ 1.5059751335472542 * PodLength
# F1 =~ 1.5254824041686028 * PodWidth
# F1 =~ 1.4200690004810044 * Seed1000W
# F1 ~ 0.5397103614410078*Ca7_6324745
# F1 ~ 0.5225634798420213*Ca7_21019002
# F1 ~ 0.4405348285572925*Ca4_46228483
# F1 ~ 0.3848079410029567*Ca4_6024498
# F1 ~ 0.3043364364413015*Ca1_18381505
# F1 ~ -0.3419223333011229*Ca5_26077864
# F1 ~ 0.2849287965440786*Ca5_23891945
# F1 ~ 0.2138033548400326*Ca3_3728574
# F1 ~ 0.19886932651142422*Ca1_40608784
# F1 ~ 0.170699599625987*Ca3_36815538
# -----------
# -----------
# F2
# FloCol
# SeedShape
# StemCol
# SeedCol
# F2 =~ 1.0 * FloCol
# F2 =~ 0.774928590147977 * StemCol
# F2 =~ -0.4395710607743179 * SeedShape
# F2 =~ 0.876961434790339 * SeedCol
# F2
# F2 =~ 1.0 * FloCol
# F2 =~ 0.774928590147977 * StemCol
# F2 =~ -0.4395710607743179 * SeedShape
# F2 =~ 0.876961434790339 * SeedCol
# -----------
# 27.89091371688565 27.890913716885642
# Skip 0 SNPs
# 0.07887188431138803
# 27.890913716885642
# 0.054751167609188744
# 11.263235136809776
# 20.875702890337777 20.875702890337777
# Skip 113 SNPs
# 0.089911339047128
# 20.875702890337777
# 0.054802030136821944
# 4.46658449277874
# 19.283790309522583 19.283790309522583
# Skip 448 SNPs
# 0.1110156726318472
# 19.283790309522583
# 0.055536521470492595
# 2.952126639461845
# 18.496491615680384 18.496491615680384
# Skip 840 SNPs
# 0.1214470329666808
# 18.496491615680384
# 0.05605592205925625
# 2.1526133939398875
# 18.04726061103519 18.04726061103519
# Skip 979 SNPs
# 0.13023399974688132
# 18.04726061103519
# 0.05721917679332833
# 1.7529961595555683
# 17.65055906952219 17.650559069522185
# Skip 1058 SNPs
# 0.16949765693221863
# 17.650559069522185
# 0.057267721046574405
# 1.2227344391956585
# 17.146858380321106 17.146858380321106
# Skip 1087 SNPs
# 0.1858849233241351
# 17.146858380321106
# 0.05763934757831768
# 0.7298165657591333
# 16.978031251689323 16.978031251689323
# Skip 1100 SNPs
# 0.2859328779418675
# 16.978031251689323
# 0.06483120199712333
# 0.5449413173902116
# 16.45012102383682 16.45012102383682
# Skip 1121 SNPs
# 0.30351242119069965
# 16.45012102383682
# 0.06935577559965456
# 0.1987396161006707
# 16.38135373009311 16.381353730093103
# Skip 1585 SNPs
# 0.3381578795647009
# 16.381353730093103
# 0.07475961942657028
# 0.15856818428137132
# F2 =~ 1.0 * FloCol
# F2 =~ 0.774928590147977 * StemCol
# F2 =~ -0.4395710607743179 * SeedShape
# F2 =~ 0.876961434790339 * SeedCol
# F2 ~ 0.6918623455385106*Ca5_26077864
# F2 ~ -0.6701214898980801*Ca7_6324745
# F2 ~ -0.6384963020142439*Ca4_46228483
# F2 ~ -0.5930071450374165*Ca6_45917082
# F2 ~ -0.6138454679360388*Ca4_15473948
# F2 ~ -0.5126324732179244*Ca7_43346567
# F2 ~ -0.46214800826694946*Ca2_33496146
# F2 ~ -0.4334630137475103*Ca4_2145082
# F2 ~ -0.37351074313278504*Ca4_3293782
# F2 ~ -0.35913088526006504*Ca4_8101219
# -----------
# -----------
# F3
# EndFBegM
# BegFEndF
# F3 =~ 1.0 * BegFEndF
# F3 =~ -0.8258969791854806 * EndFBegM
# F3
# F3 =~ 1.0 * BegFEndF
# F3 =~ -0.8258969791854806 * EndFBegM
# -----------
# 11.4411666695344 11.4411666695344
# Skip 0 SNPs
# 0.0028921205383030113
# 11.4411666695344
# 0.00015331788544248326
# 9.079899932825251
# 6.818018944777919 6.818018944777919
# Skip 276 SNPs
# 0.012832499988359558
# 6.818018944777919
# 6.965984092222044e-05
# 4.097898437149643
# 5.1052565570518516 5.1052565570518516
# Skip 533 SNPs
# 0.017261756269557615
# 5.1052565570518516
# 0.00034499561770706677
# 2.4553562377131364
# 4.499608798416008 4.499608798416008
# Skip 809 SNPs
# 0.01778914154704303
# 4.499608798416008
# 0.000506635348601181
# 1.6233280915281636
# 4.026775868634571 4.026775868634571
# Skip 943 SNPs
# 0.02016619503741346
# 4.026775868634571
# 0.0011771200268775317
# 1.2717841099329839
# 3.3107929819977198 3.3107929819977198
# Skip 1099 SNPs
# 0.020448141181126367
# 3.3107929819977198
# 0.0011950588689506603
# 0.8011047628023613
# 3.1872410407467857 3.1872410407467857
# Skip 1201 SNPs
# 0.025112855730723638
# 3.1872410407467857
# 0.000959658863357804
# 0.5152643865293243
# 3.433746270586239 3.433746270586239
# Skip 1250 SNPs
# 0.03587522228715656
# 3.433746270586239
# 0.002093311743775139
# 0.6389458095701039
# 3.142862359918542 3.142862359918542
# Skip 1268 SNPs
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# 0.03759819244963225
# 3.142862359918542
# 0.0020946195744051543
# 0.44977110943860676
# 3.063996332633419 3.063996332633419
# Skip 1516 SNPs
# 0.03962637976141181
# 3.063996332633419
# 0.002146871785424276
# 0.447272708450984
# F3 =~ 1.0 * BegFEndF
# F3 =~ -0.8258969791854806 * EndFBegM
# F3 ~ 0.6087237997763335*Ca7_32482435
# F3 ~ -0.49489714656397876*Ca7_36747540
# F3 ~ 0.41595465967365775*Ca3_19353482
# F3 ~ -0.37868104870249386*Ca3_9387546
# F3 ~ 0.3382923031488677*Ca6_53592514
# F3 ~ 0.33260993629367647*Ca3_28437425
# F3 ~ -0.26303926302872976*Ca2_27434688
# F3 ~ 0.2769515036653856*Ca1_5480709
# F3 ~ 0.2521410734598684*Ca6_15283408
# F3 ~ -0.2586705782226478*Ca2_35983700
# -----------
# -----------
# F4
# Height
# Hlp
# F4 =~ 1.0 * Height
# F4 =~ 0.596711045528099 * Hlp
# F4
# F4 =~ 1.0 * Height
# F4 =~ 0.596711045528099 * Hlp
# -----------
# 16.821502530226052 16.821502530226056
# Skip 0 SNPs
# 0.00021912807151980296
# 16.821502530226056
# 4.7155992312308825e-05
# 8.378456180666763
# 9.850589977601322 9.850589977601322
# Skip 142 SNPs
# 0.0015938292489048322
# 9.850589977601322
# 0.00013183683148559888
# 1.2460785949948967
# 9.305954751761192 9.305954751761192
# Skip 863 SNPs
# 0.006662560184444999
# 9.305954751761192
# 0.00015720220400777807
# 0.6589775621693725
# 9.112661770695512 9.112661770695507
# Skip 1115 SNPs
# 0.015331640323356766
# 9.112661770695507
# 0.0011674873464235236
# 0.5083375159787895
# 8.897120536733933 8.897120536733933
# Skip 1281 SNPs
# 0.03044163282859369
# 8.897120536733933
# 0.003109980547882474
# 0.32660079290480226
# 8.666372273563418 8.666372273563418
# Skip 1388 SNPs
# 0.032366013061257526
# 8.666372273563418
# 0.0030607055016949603
# 0.1883326431132808
# 8.643646324717986 8.643646324717986
# Skip 1712 SNPs
# 0.0380583084639774
# 8.643646324717986
# 0.003748863918135087
# 0.17492914353477218
# 8.613240258842042 8.61324025884204
# Skip 1839 SNPs
# 0.0494970815523299
# 8.61324025884204
# 0.005425977245487823
# 0.11234501415418485
# 8.536375943673214 8.536375943673214
# Skip 1911 SNPs
# 0.052011971055508255
# 8.536375943673214
# 0.0053875356441254185
# 0.07283584763832707
# 8.528820042559873 8.52882004255989
# Skip 2020 SNPs
# 0.058878033865020996
# 8.52882004255989
# 0.005380324563437844
# 0.05898887392043051
# F4 =~ 1.0 * Height
# F4 =~ 0.596711045528099 * Hlp
# F4 ~ -0.8623007995772515*Ca5_21382177
# F4 ~ -0.672233094470025*Ca5_7292272
# F4 ~ 0.4474570668649968*Ca8_6273309
# F4 ~ 0.44224765693121526*Ca2_20913309
# F4 ~ -0.4210175082933749*Ca7_38775034
# F4 ~ -0.42551988236022315*Ca6_52918228
# F4 ~ 0.3821750375755655*Ca3_33987268
# F4 ~ -0.34001427182007493*Ca3_28094292
# F4 ~ -0.29422651698980407*Ca7_41892029
# F4 ~ 0.2779802227643402*Ca7_6324745
# -----------
# -----------
